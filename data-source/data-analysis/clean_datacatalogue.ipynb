# %%
import pandas as pd
# import csv, indicate data type for certain date columns to be integer
df = pd.read_csv('data/SPA_DataCatalogue_250822_NDSAP-aligned_updated.csv', dtype={'date_earliest': 'Int64', 'date_latest': 'Int64'})
df.head()
# Out:
#    id                                              title  \
# 0   1                          Villages In Jaipur Region
# 1   2                    Gram Panchayat Of Jaipur Region
# 2   3                   Evolution Of Jaipur Urban Extent
# 3   4                          Zones And Wards In Jaipur
# 4   5  List Of Existing Towns With Present Population...
#
#                                          description  \
# 0  This dataset provides names of villages in Jai...
# 1  This dataset provides boundaries for Gram Panc...
# 2  This dataset provides the information The grow...
# 3  This dataset provides boundaries for zones and...
# 4  List of existing town with present population,...
#
#                              keywords                                  group  \
# 0            villages; administrative                        master plan map
# 1          gram panchayat; boundaries                        master plan map
# 2  built up; urban area; urban growth  L&T Infra Engineering Transport Study
# 3          administrative; boundaries                        master plan map
# 4     towns; population; connectivity                       master plan data
#
#                    sector              jurisdiction frequency  \
# 0  Administrative Context           Jaipur District   unknown
# 1  Administrative Context  Jaipur Urban Area (2018)   unknown
# 2  Administrative Context                City level   unknown
# 3  Administrative Context           Jaipur District   unknown
# 4  Administrative Context           Jaipur District   unknown
#
#   granularity_spatial granularity_temporal  date_earliest  date_latest  \
# 0            district             one-time           <NA>         2011
# 1              region             one-time           <NA>         2011
# 2              region             one-time           1989         2014
# 3            district             one-time           <NA>         2001
# 4            district             one-time           <NA>         2001
#
#   access_type         format provider  \
# 0        open    printed map      JDA
# 1        open    printed map      JDA
# 2     private    printed map      JDA
# 3        open    printed map      JDA
# 4        open  printed table      JDA
#
#                                            reference  \
# 0  JDA (2011) Master Development Plan 2025, vol1,...
# 1  JDA (2011) Master Development Plan 2025, vol1,...
# 2  L&T Infra Engineering (2022) Comprehensive Tra...
# 3  JDA (2011) Master Development Plan 2025, vol1,...
# 4  JDA (2011) Master Development Plan 2025, vol1,...
#
#                                                  url            access_method
# 0  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 1  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 2                         Document not yet published  Not currently available
# 3  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 4  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL

# %%
df.columns
# Out:
# Index(['id', 'title', 'description', 'keywords', 'group', 'sector',
#        'jurisdiction', 'frequency', 'granularity_spatial',
#        'granularity_temporal', 'date_earliest', 'date_latest', 'access_type',
#        'format', 'provider', 'reference', 'url', 'access_method'],
#       dtype='object')

# %%
# Change case for certain columns
df['title'] = df['title'].str.upper()
df['description'] = df['title'].str.capitalize()
df['group'] = df['group'].str.title()
df['sector'] = df['sector'].str.title()
df['frequency'] = df['frequency'].str.capitalize()
df['granularity_spatial'] = df['granularity_spatial'].str.capitalize()
df['granularity_temporal'] = df['granularity_temporal'].str.capitalize()
df['access_type'] = df['access_type'].str.capitalize()
df['format'] = df['format'].str.capitalize()

# Fix 'Cd block'=> 'CD Block'
df['granularity_spatial'] = df['granularity_spatial'].str.replace('Cd block / town', 'CD Block / Town', regex=False)

# Fix Format 
df['format'] = df['format'].str.replace('Csv', 'CSV', regex=False)
df['format'] = df['format'].str.replace('Xls/xlsx', 'XLS/XLSX', regex=False)
df['format'] = df['format'].str.replace('Json', 'JSON', regex=False)
df['format'] = df['format'].str.replace('Zip', 'ZIP', regex=False)
df['format'] = df['format'].str.replace('Geotiff image', 'GeoTIFF image', regex=False)
df['format'] = df['format'].str.replace('Shapefile', 'ESRI Shapefile', regex=False)
df.head()
# Out:
#    id                                              title  \
# 0   1                          VILLAGES IN JAIPUR REGION
# 1   2                    GRAM PANCHAYAT OF JAIPUR REGION
# 2   3                   EVOLUTION OF JAIPUR URBAN EXTENT
# 3   4                          ZONES AND WARDS IN JAIPUR
# 4   5  LIST OF EXISTING TOWNS WITH PRESENT POPULATION...
#
#                                          description  \
# 0                          Villages in jaipur region
# 1                    Gram panchayat of jaipur region
# 2                   Evolution of jaipur urban extent
# 3                          Zones and wards in jaipur
# 4  List of existing towns with present population...
#
#                              keywords                                  group  \
# 0            villages; administrative                        Master Plan Map
# 1          gram panchayat; boundaries                        Master Plan Map
# 2  built up; urban area; urban growth  L&T Infra Engineering Transport Study
# 3          administrative; boundaries                        Master Plan Map
# 4     towns; population; connectivity                       Master Plan Data
#
#                    sector              jurisdiction frequency  \
# 0  Administrative Context           Jaipur District   Unknown
# 1  Administrative Context  Jaipur Urban Area (2018)   Unknown
# 2  Administrative Context                City level   Unknown
# 3  Administrative Context           Jaipur District   Unknown
# 4  Administrative Context           Jaipur District   Unknown
#
#   granularity_spatial granularity_temporal  date_earliest  date_latest  \
# 0            District             One-time           <NA>         2011
# 1              Region             One-time           <NA>         2011
# 2              Region             One-time           1989         2014
# 3            District             One-time           <NA>         2001
# 4            District             One-time           <NA>         2001
#
#   access_type         format provider  \
# 0        Open    Printed map      JDA
# 1        Open    Printed map      JDA
# 2     Private    Printed map      JDA
# 3        Open    Printed map      JDA
# 4        Open  Printed table      JDA
#
#                                            reference  \
# 0  JDA (2011) Master Development Plan 2025, vol1,...
# 1  JDA (2011) Master Development Plan 2025, vol1,...
# 2  L&T Infra Engineering (2022) Comprehensive Tra...
# 3  JDA (2011) Master Development Plan 2025, vol1,...
# 4  JDA (2011) Master Development Plan 2025, vol1,...
#
#                                                  url            access_method
# 0  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 1  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 2                         Document not yet published  Not currently available
# 3  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 4  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL

# %%
# Clean up some non-working URLs
df['url'] = df['url'].replace('Jaipur City Mobility Plan', 'https://cuts-ccier.org/pdf/jaipur-city-mobility-plan.pdf')
df['url'] = df['url'].replace('Document not yet published', None)

# %%
# add url_download column for id 290 to https://orca.casa.ucl.ac.uk/~jens/sparc-dash/download/census2011.zip
df.loc[df.id == 290, 'url_download'] = 'https://orca.casa.ucl.ac.uk/~jens/sparc-dash/download/census2011.zip'
df[df.id == 290]
# Out:
#       id               title         description  \
# 240  290  CENSUS WARD COUNTS  Census ward counts
#
#                                               keywords group        sector  \
# 240  age; gender; sex; literacy; workers; industry;...   NaN  Demographics
#
#         jurisdiction frequency granularity_spatial granularity_temporal  \
# 240  Jaipur District   Unknown                Ward             One-time
#
#      date_earliest  date_latest access_type    format         provider  \
# 240           <NA>         2011        Open  XLS/XLSX  Census of India
#
#                    reference  \
# 240  Census of India website
#
#                                                    url     access_method  \
# 240  https://censusindia.gov.in/census.website/data...  Go to source URL
#
#                                           url_download
# 240  https://orca.casa.ucl.ac.uk/~jens/sparc-dash/d...

# %%
# Add column lastupdated_group into last 2 years, 5 years, 10 years, etc.
import datetime
current_year = datetime.datetime.now().year
def lastupdated_group(year, yearlist=[2,5,10,15,20]):
    if year == 'N/A':
        return 'N/A'
    counter = 0
    for i in yearlist:
        if current_year - year <= i:
            return f'Last {i} yrs'
        counter += 1
    return f'{yearlist[counter-1]+1} yrs or older'
  
df['lastupdate'] = df['date_latest'].apply(lastupdated_group)                           
df.head()
# Out:
#    id                                              title  \
# 0   1                          VILLAGES IN JAIPUR REGION
# 1   2                    GRAM PANCHAYAT OF JAIPUR REGION
# 2   3                   EVOLUTION OF JAIPUR URBAN EXTENT
# 3   4                          ZONES AND WARDS IN JAIPUR
# 4   5  LIST OF EXISTING TOWNS WITH PRESENT POPULATION...
#
#                                          description  \
# 0                          Villages in jaipur region
# 1                    Gram panchayat of jaipur region
# 2                   Evolution of jaipur urban extent
# 3                          Zones and wards in jaipur
# 4  List of existing towns with present population...
#
#                              keywords                                  group  \
# 0            villages; administrative                        Master Plan Map
# 1          gram panchayat; boundaries                        Master Plan Map
# 2  built up; urban area; urban growth  L&T Infra Engineering Transport Study
# 3          administrative; boundaries                        Master Plan Map
# 4     towns; population; connectivity                       Master Plan Data
#
#                    sector              jurisdiction frequency  \
# 0  Administrative Context           Jaipur District   Unknown
# 1  Administrative Context  Jaipur Urban Area (2018)   Unknown
# 2  Administrative Context                City level   Unknown
# 3  Administrative Context           Jaipur District   Unknown
# 4  Administrative Context           Jaipur District   Unknown
#
#   granularity_spatial granularity_temporal  date_earliest  date_latest  \
# 0            District             One-time           <NA>         2011
# 1              Region             One-time           <NA>         2011
# 2              Region             One-time           1989         2014
# 3            District             One-time           <NA>         2001
# 4            District             One-time           <NA>         2001
#
#   access_type         format provider  \
# 0        Open    Printed map      JDA
# 1        Open    Printed map      JDA
# 2     Private    Printed map      JDA
# 3        Open    Printed map      JDA
# 4        Open  Printed table      JDA
#
#                                            reference  \
# 0  JDA (2011) Master Development Plan 2025, vol1,...
# 1  JDA (2011) Master Development Plan 2025, vol1,...
# 2  L&T Infra Engineering (2022) Comprehensive Tra...
# 3  JDA (2011) Master Development Plan 2025, vol1,...
# 4  JDA (2011) Master Development Plan 2025, vol1,...
#
#                                                  url            access_method  \
# 0  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 1  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 2                                               None  Not currently available
# 3  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 4  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
#
#   url_download       lastupdate
# 0          NaN      Last 15 yrs
# 1          NaN      Last 15 yrs
# 2          NaN      Last 15 yrs
# 3          NaN  21 yrs or older
# 4          NaN  21 yrs or older

# %%
df.head()
# Out:
#    id                                              title  \
# 0   1                          VILLAGES IN JAIPUR REGION
# 1   2                    GRAM PANCHAYAT OF JAIPUR REGION
# 2   3                   EVOLUTION OF JAIPUR URBAN EXTENT
# 3   4                          ZONES AND WARDS IN JAIPUR
# 4   5  LIST OF EXISTING TOWNS WITH PRESENT POPULATION...
#
#                                          description  \
# 0                          Villages in jaipur region
# 1                    Gram panchayat of jaipur region
# 2                   Evolution of jaipur urban extent
# 3                          Zones and wards in jaipur
# 4  List of existing towns with present population...
#
#                              keywords                                  group  \
# 0            villages; administrative                        Master Plan Map
# 1          gram panchayat; boundaries                        Master Plan Map
# 2  built up; urban area; urban growth  L&T Infra Engineering Transport Study
# 3          administrative; boundaries                        Master Plan Map
# 4     towns; population; connectivity                       Master Plan Data
#
#                    sector              jurisdiction frequency  \
# 0  Administrative Context           Jaipur District   Unknown
# 1  Administrative Context  Jaipur Urban Area (2018)   Unknown
# 2  Administrative Context                City level   Unknown
# 3  Administrative Context           Jaipur District   Unknown
# 4  Administrative Context           Jaipur District   Unknown
#
#   granularity_spatial granularity_temporal  date_earliest  date_latest  \
# 0            District             One-time           <NA>         2011
# 1              Region             One-time           <NA>         2011
# 2              Region             One-time           1989         2014
# 3            District             One-time           <NA>         2001
# 4            District             One-time           <NA>         2001
#
#   access_type         format provider  \
# 0        Open    Printed map      JDA
# 1        Open    Printed map      JDA
# 2     Private    Printed map      JDA
# 3        Open    Printed map      JDA
# 4        Open  Printed table      JDA
#
#                                            reference  \
# 0  JDA (2011) Master Development Plan 2025, vol1,...
# 1  JDA (2011) Master Development Plan 2025, vol1,...
# 2  L&T Infra Engineering (2022) Comprehensive Tra...
# 3  JDA (2011) Master Development Plan 2025, vol1,...
# 4  JDA (2011) Master Development Plan 2025, vol1,...
#
#                                                  url            access_method  \
# 0  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 1  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 2                                               None  Not currently available
# 3  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
# 4  https://jda.rajasthan.gov.in/content/dam/raj/u...         Go to source URL
#
#   url_download       lastupdate
# 0          NaN      Last 15 yrs
# 1          NaN      Last 15 yrs
# 2          NaN      Last 15 yrs
# 3          NaN  21 yrs or older
# 4          NaN  21 yrs or older

# %%
df.to_json('../../public/data/datacatalogue.json', orient='records', indent=4)
