# %%
import pandas as pd
df = pd.read_csv('SPA_DataCatalogue_KPIs(Catalogue).csv')

# %%
df = df[[
    'id',
    'data_display_name',
    'description',
    'theme',
    'geog_level2',
    'format2',
    'provider',
    'reference',
    'reference table/fig/pgno',
    'latest_year',
    'update_freq2',
    'url'
]]

# %%
df =df.rename(columns={
    'data_display_name': 'name',
    'geog_level2': 'geography',
    'format2': 'format',
    'reference table/fig/pgno': 'reference_ref',
    'update_freq2': 'update_frequency'
})

df.head()
# Out:
#    id                                               name  \
# 0   1                          Villages In Jaipur Region
# 1   2                    Gram Panchayat Of Jaipur Region
# 2   3                   Evolution Of Jaipur Urban Extent
# 3   4                          Zones And Wards In Jaipur
# 4   5  List Of Existing Towns With Present Population...
#
#                                          description                   theme  \
# 0  This dataset provides names of villages in Jai...  Administrative Context
# 1  This dataset provides boundaries for Gram Panc...  Administrative Context
# 2  This dataset provides the information The grow...  Administrative Context
# 3  This dataset provides boundaries for zones and...  Administrative Context
# 4  List of existing town with present population,...  Administrative Context
#
#   geography         format provider  \
# 0  district    printed map      JDA
# 1    region    printed map      JDA
# 2    region    printed map      JDA
# 3  district    printed map      JDA
# 4  district  printed table      JDA
#
#                                            reference  \
# 0      JDA (2011) Master Development Plan 2025, vol1
# 1      JDA (2011) Master Development Plan 2025, vol1
# 2  L&T Infra Engineering (2022) Comprehensive Tra...
# 3      JDA (2011) Master Development Plan 2025, vol1
# 4      JDA (2011) Master Development Plan 2025, vol1
#
#                     reference_ref  latest_year update_frequency  \
# 0  Heading 2.8, map on pg no. 109       2011.0          unknown
# 1                Map 3-3, pg. 131       2011.0          unknown
# 2              Figure 6-1, Pg 6-2       2014.0          unknown
# 3                Map 3-2, pg. 130       2001.0          unknown
# 4             Table 2-39, pg. 121       2001.0          unknown
#
#                                                  url
# 0  https://jda.rajasthan.gov.in/content/dam/raj/u...
# 1  https://jda.rajasthan.gov.in/content/dam/raj/u...
# 2                         Document not yet published
# 3  https://jda.rajasthan.gov.in/content/dam/raj/u...
# 4  https://jda.rajasthan.gov.in/content/dam/raj/u...

# %%
df.to_csv('datacatalogue/datacatalogue.csv', index=False)
